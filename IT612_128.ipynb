# %% [markdown]
# <a href="https://colab.research.google.com/github/wytonkin/IT612/blob/main/IT612_128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# const addTax = (price, rate) => {
#   return price + (price * rate);
# }
#
# console.log(addTax(100, 0.1));
# console.log(addTax(200, 0.2));
# console.log(addTax(300, 0.3));
#
#
# function createBurner(secret, limit) {
#   lim = limit;
#   return function() {
#     for (let i = 0; i < lim; i++) {
#       console.log(secret);
#     }
#   }
# }
# console.log(createBurner(2, 10));
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# 110
# 240
# 390
# [Function (anonymous)]
