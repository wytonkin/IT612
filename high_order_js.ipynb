# %% [markdown]
# <a href="https://colab.research.google.com/github/wytonkin/IT612/blob/main/high_order_js.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# //Part A
#
# //loop way
# const data = [5, 12, 3, 20, 11, 9, 30];
#  let len = data.length;
#  let moreTen = [];
#  for (let i = 0; i < len; i++) {
#   if (data[i] > 10) {
#     moreTen.push(data[i] * 2);
#   }
#  }
#   console.log(moreTen);
# //filter way
#   const moreTen2 = data
#   .filter((item) => item > 10)
#   .map((item) => item * 2);
#   console.log(moreTen2);
# //Part B
# console.log("\n")
# const numbers = [1, 2, 3, 4, 5, 6];
#
# const doubledEvens = numbers
# .filter((number) => number % 2 === 0)
# .map((number) => number * 2);
#
# const sum = doubledEvens.reduce(function (x, y) {
#   return x + y;
# }, 0);
#
# console.log(sum);
# //Part C
# console.log("\n")
# const users = [
#   { id: 1, name: "Alice", age: 25 },
#   { id: 2, name: "Bob", age: 17 },
#   { id: 3, name: "Carol", age: 19 }
# ];
#
# const minor = users.some(user => user.age < 18);
# console.log(minor);
#
# const id = users.find( user => user.id === 3);
# console.log(id);
#
# const each = users.forEach(user => console.log(user.name));
# //Part D
# console.log("\n")
#
# function repeat(n, action) {
#   // TODO: call action(i) for i = 0..n-1
#   for (let i = 0; i < n; i++) {
#     action(i);
#   }
# }
#
# repeat(3, console.log);
# repeat(4, i => console.log("Step " + i));
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# [ 24, 40, 22, 60 ]
# [ 24, 40, 22, 60 ]
#
#
# 24
#
#
# true
# { id: 3, name: 'Carol', age: 19 }
# Alice
# Bob
# Carol
#
#
# 0
# 1
# 2
# Step 0
# Step 1
# Step 2
# Step 3
